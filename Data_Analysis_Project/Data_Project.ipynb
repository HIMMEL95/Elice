# %% [markdown]
# # 위키피디아 데이터 엑셀로 저장하기

# %%
import pandas as pd
import numpy as np

df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')

new_df = df[1].iloc[:,:6]
new_df.drop(152, inplace=True)
new_df.columns = ['팀','경기수', '금', '은', '동', '계']
df1 = new_df.sort_values(by='금', ascending=False)

df1.to_excel('하계올림픽메달.xlsx', index=False)

# %% [markdown]
# # pandas로 인구 구조 분석하기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('age.csv', encoding = 'cp949', index_col=0)
df.drop('연령구간인구수', axis=1, inplace=True)
df= df.div(df[df.columns[0]], axis=0)
df.drop('총인구수', axis=1, inplace=True)
df= df.mul(100)

name = input()
a = df[df.index.str.contains(name)]

xvalue = a.columns.to_list()
yvalue = a.values.ravel().tolist()

plt.figure(figsize=(50,25))
plt.rc('font', family='NanumGothic')
plt.title(f'{a.index[0]} 지역의 0세~100세 이상의 인구 비율 (n세 인구수/ 전체 인구수)')
plt.plot(xvalue, yvalue)
plt.xticks(rotation=90)
plt.show()
